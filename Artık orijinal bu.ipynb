# %%
import pandas as pd
df=pd.read_csv("Lastik.csv")
import seaborn as sns
import matplotlib.pyplot as plt
df
# Out:
#       Unnamed: 0    Fabrikalar  Mudur_Sayisi  Mudur_Maasi  Mudur_Puani  \
# 0              0     Fabrika 1             9       11.282            9
# 1              1     Fabrika 2            13       10.190            8
# 2              2     Fabrika 3            14       13.708            9
# 3              3     Fabrika 4            10       10.035            8
# 4              4     Fabrika 5            12       14.617            6
# ...          ...           ...           ...          ...          ...
# 996          996   Fabrika 997            15        7.569            7
# 997          997   Fabrika 998            11       14.009            6
# 998          998   Fabrika 999            15       10.911           10
# 999          999  Fabrika 1000             8       10.818            9
# 1000        1000  Fabrika 1001            13       14.688            6
#
#       Calisan_Sayisi  Calisan_Maasi  Calisan_Puani  \
# 0               4601           6600              7
# ...

# %%
df[["Veri_Analizi_Mudur_Sayisi","Veri_Analizi_Mudur_Puani"]]
# Out:
#       Veri_Analizi_Mudur_Sayisi  Veri_Analizi_Mudur_Puani
# 0                             8                        10
# 1                             7                        10
# 2                             8                        10
# 3                             6                        10
# 4                            10                        10
# ...                         ...                       ...
# 996                           5                        10
# 997                           7                        10
# 998                           6                        10
# 999                           8                        10
# 1000                          8                        10
#
# [1001 rows x 2 columns]

# %%
Veri=df[["Veri_Analizi_Mudur_Sayisi","Veri_Analizi_Mudur_Puani"]]

# %%
sns.displot(Veri)

# %%
df[["Calisan_Sayisi","Calisan_Puani"]]
# Out:
#       Calisan_Sayisi  Calisan_Puani
# 0               4601              7
# 1               5607             10
# 2               6332              8
# 3               6502              6
# 4               6352              8
# ...              ...            ...
# 996             5199              6
# 997             4888              9
# 998             7032              5
# 999             7431             10
# 1000            6605             10
#
# [1001 rows x 2 columns]

# %%
Calisan=df[["Calisan_Sayisi","Calisan_Puani"]]

# %%
sns.displot(Calisan)

# %%
df[["Uretim_Miktari","Uretim_Hizi","Urun_Hata_Orani" ]]
# Out:
#       Uretim_Miktari  Uretim_Hizi  Urun_Hata_Orani
# 0             326996            6                5
# 1             467492            7                2
# 2             310513           10                1
# 3             424575            9                2
# 4             397558            8                3
# ...              ...          ...              ...
# 996           427194            7                3
# 997           174780            8                1
# 998           166936            8                5
# 999           267247            9                2
# 1000          208754            9                2
#
# [1001 rows x 3 columns]

# %%
Uretim=df[["Uretim_Miktari","Uretim_Hizi","Urun_Hata_Orani" ]]

# %%
sns.displot(Uretim)

# %%
df[["SUV_Lastik_Performansi","Yazlik_Lastik_Performansi","Dort_Mevsim_Lastik_Performansi","Kislik_Lastik_Performansi"]]
# Out:
#       SUV_Lastik_Performansi  Yazlik_Lastik_Performansi  \
# 0                          8                          8
# 1                          6                          8
# 2                          8                         10
# 3                          8                          8
# 4                          9                         10
# ...                      ...                        ...
# 996                        9                         10
# 997                        7                          8
# 998                        7                          9
# 999                        5                          9
# 1000                       6                         10
#
#       Dort_Mevsim_Lastik_Performansi  Kislik_Lastik_Performansi
# 0                                  5                          6
# 1                                  7                          6
# 2                                  5                          7
# ...

# %%
Performans=df[["SUV_Lastik_Performansi","Yazlik_Lastik_Performansi","Dort_Mevsim_Lastik_Performansi","Kislik_Lastik_Performansi"]]

# %%
sns.displot(Performans)

# %%
df[["SUV_Lastik_Satis","Yazlik_Lastik_Satis","Dort_Mevsim_Lastik_Satis","Kislik_Lastik_Satis"]]
# Out:
#       SUV_Lastik_Satis  Yazlik_Lastik_Satis  Dort_Mevsim_Lastik_Satis  \
# 0                    4                    9                         4
# 1                    3                    7                         3
# 2                    4                    9                         3
# 3                    1                    7                         3
# 4                    1                    7                         5
# ...                ...                  ...                       ...
# 996                  3                    9                         3
# 997                  2                    7                         3
# 998                  4                    7                         5
# 999                  2                    7                         4
# 1000                 3                    7                         4
#
#       Kislik_Lastik_Satis
# 0                       5
# 1                       6
# 2                       7
# ...

# %%
Satis=df[["SUV_Lastik_Satis","Yazlik_Lastik_Satis","Dort_Mevsim_Lastik_Satis","Kislik_Lastik_Satis"]]

# %%
sns.displot(Satis)

# %%
df[["SUV_Lastik_Maliyeti","Yazlik_Lastik_Maliyeti","Dort_Mevsim_Lastik_Maliyeti","Kislik_Lastik_Maliyeti"]]
# Out:
#       SUV_Lastik_Maliyeti  Yazlik_Lastik_Maliyeti  \
# 0                       6                       3
# 1                       7                       3
# 2                       8                       3
# 3                       7                       4
# 4                       7                       5
# ...                   ...                     ...
# 996                     8                       3
# 997                     8                       5
# 998                     8                       3
# 999                     8                       5
# 1000                    7                       3
#
#       Dort_Mevsim_Lastik_Maliyeti  Kislik_Lastik_Maliyeti
# 0                               6                       6
# 1                               5                       6
# 2                               5                       5
# 3                               8                       7
# 4                               5                       6
# ...

# %%
Maliyet=df[["SUV_Lastik_Maliyeti","Yazlik_Lastik_Maliyeti","Dort_Mevsim_Lastik_Maliyeti","Kislik_Lastik_Maliyeti"]]

# %%
sns.displot(Maliyet)

# %%
df[["Lojistik_Sayisi","Lojistik_Puani"]]
# Out:
#       Lojistik_Sayisi  Lojistik_Puani
# 0                  33               5
# 1                  38               5
# 2                  50               8
# 3                  26               8
# 4                  35               8
# ...               ...             ...
# 996                48               9
# 997                48               6
# 998                50               5
# 999                36               7
# 1000               50               5
#
# [1001 rows x 2 columns]

# %%
Lojistik=df[["Lojistik_Sayisi","Lojistik_Puani"]]

# %%
sns.displot(Lojistik)

# %%
df["Kaucuk_Kalitesi"]
# Out:
# 0        6
# 1        6
# 2        7
# 3        9
# 4        9
#         ..
# 996      9
# 997      8
# 998      9
# 999      8
# 1000    10
# Name: Kaucuk_Kalitesi, Length: 1001, dtype: int64

# %%
Kaucuk=df["Kaucuk_Kalitesi"]

# %%
sns.displot(Kaucuk)

# %%
df["Konfor"]
# Out:
# 0       5
# 1       5
# 2       9
# 3       5
# 4       5
#        ..
# 996     6
# 997     5
# 998     5
# 999     8
# 1000    9
# Name: Konfor, Length: 1001, dtype: int64

# %%
Konfor=df["Konfor"]

# %%
sns.displot(Konfor)

# %%
df["Yakit_Tuketimi"]
# Out:
# 0        8
# 1        8
# 2        6
# 3        8
# 4       10
#         ..
# 996      8
# 997      6
# 998      8
# 999      9
# 1000    10
# Name: Yakit_Tuketimi, Length: 1001, dtype: int64

# %%
Yakit=df["Yakit_Tuketimi"]

# %%
sns.displot(Yakit)

# %%
df["Asinma"]
# Out:
# 0        5
# 1        8
# 2        8
# 3        9
# 4       10
#         ..
# 996      6
# 997      6
# 998      5
# 999     10
# 1000     5
# Name: Asinma, Length: 1001, dtype: int64

# %%
Asinma=df["Asinma"]

# %%
sns.displot(Asinma)

# %%
df.shape
#Kaç veri olduğunu gösterir.
# Out:
# (1001, 81)

# %%
df.isna()
#Kayıp verileri bulma.
# Out:
#       Unnamed: 0  Fabrikalar  Mudur_Sayisi  Mudur_Maasi  Mudur_Puani  \
# 0          False       False         False        False        False
# 1          False       False         False        False        False
# 2          False       False         False        False        False
# 3          False       False         False        False        False
# 4          False       False         False        False        False
# ...          ...         ...           ...          ...          ...
# 996        False       False         False        False        False
# 997        False       False         False        False        False
# 998        False       False         False        False        False
# 999        False       False         False        False        False
# 1000       False       False         False        False        False
#
#       Calisan_Sayisi  Calisan_Maasi  Calisan_Puani  \
# 0              False          False          False
# ...
